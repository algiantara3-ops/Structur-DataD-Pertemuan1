# %% [markdown]
# <a href="https://colab.research.google.com/github/algiantara3-ops/Structur-DataD-Pertemuan1/blob/main/Salinan_dari_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mahasiswa = ["driga", "algian", "manik", "dode", "kayana"]
print("list mahasiswa")
print(mahasiswa)
# Out:
# list mahasiswa
# ['driga', 'algian', 'manik', 'dode', 'kayana']

# %%
mahasiswa.append ("dirga")
print("setelah ditambahkan nama baru")
print(mahasiswa)
# Out:
# setelah ditambahkan nama baru
# ['driga', 'algian', 'manik', 'dode', 'kayana', 'dirga']

# %%
mahasiswa.remove ("manik")
print("setelah menghapus nama dirga")
print(mahasiswa)
# Out:
# setelah menghapus nama dirga
# ['driga', 'algian', 'dode', 'kayana', 'dirga']
